# %%
import pandas as pd 
import numpy as np
df = pd.read_excel('/home/pratik/Downloads/DCHB_Town_Release_1900.xlsx')
# Out:
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
pd.options.display.max_seq_items = 2000

# %%
df.columns
# Out:
# Index(['State Code', 'State Name', 'District Code', 'District Name',
#        'Sub District Code', 'Sub District Name', 'Town Code', 'Town Name',
#        'Total   Households ', 'Total Population of Town',
#        'Total Male Population of Town', 'Total Female Population of Town',
#        'Total Scheduled Castes Population of Town',
#        'Total Scheduled Castes  Male Population of Town',
#        'Total Scheduled Castes  Female Population of Town',
#        'Total Scheduled Tribes Population of Town',
#        'Total Scheduled Tribes  Male Population of Town',
#        'Total Scheduled Tribes  Female Population of Town', 'Reference Year',
#        'Class', 'Civic Status of Town',
#        'Name of Taluk/Tahsil/Police Station/Islands etc.', 'Name of CD Block',
#        'Area (sq. km.)',
#        'Number of Households including Houseless Households (2011 Census)',
#        'Scheduled Castes Population (2011 Census)',
#        'Scheduled Tribes Population (2011 Census)',
# ...

# %%
df1 = df[df['District Name'] == "SOUTH  TWENTY FOUR PARGANAS"]
df1.shape
# Out:
# (118, 429)

# %%
df2 = df1[['State Name',
 'District Name',
 'Sub District Name',
 'Town Name','Total   Households ',
 'Total Population of Town',
 'Total Male Population of Town',
 'Total Female Population of Town','Area (sq. km.)',
 'Number of Households including Houseless Households (2011 Census)','Town Population (Census 2011)',
    'Growth Rate Town (Census 2011)',
 'Density (Census 2011)','Sex Ratio (Census 2011)',
    'Nearest Ciity with Population of 5 Lakh and more Road Distance (in kms.) ',
    'Latrines-Pit (Numbers)',
 'Latrines-Others (Numbers)','Hospital Allopathic (Numbers)',
 'Hospital Allopathic Beds (Numbers)',
 'Hospital Allopathic Doctors-Total Strength (Numbers)',
 'Hospital Allopathic Doctors-In Position (Numbers)',
 'Hospital Allopathic Para Medical Staff-Total Strength (Numbers)',
 'Hospital Allopathic Para Medical Staff-In Postion (Numbers)',
 'Hospital Allopathic Nearest facility Distance (in Kms.)',
 'Hospital Alternative Medicine (Numbers)',
 'Hospital Alternative Medicine Beds (Numbers)',
 'Hospital Alternative Medicine Doctors-Total Strength (Numbers) ',
 'Hospital Alternative Medicine Doctors-In Position (Numbers)',
 'Hospital Alternative Medicine Para Medical Staff-Total Strength (Numbers)',
 'Hospital Alternative Medicine Para Medical Staff-In Position (Numbers)',
 'Hospital Alternative Medicine Nearest facility Distance(in kms.)',
 'Dispensary/Health Centre (Numbers)',
 'Dispensary/Health Centre Beds (Numbers)',
 'Dispensary/Health Centre Doctors-Total Strength (Numbers)',
 'Dispensary/Health Centre Doctors-In Position (Numbers)',
 'Dispensary/Health Centre Para Medical Staff-Total Strength (Numbers)',
 'Dispensary/Health Centre Para Medical Staff-In Position (Numbers)',
 'Dispensary/Health Centre Nearest facility Distance (in Kms.)',
 'Family Welfare Centre (Numbers)',
 'Family Welfare Centre Beds (Numbers)',
 'Family Welfare Centre Doctors-Total Strength (Numbers)',
 'Family Welfare Centre Doctors-In Position (Numbers)',
 'Family Welfare Centre Doctors Para Medical Staff-Total Strength (Numbers)',
 'Family Welfare Centre Para Medical Staff-In Position (Numbers)',
 'Family Welfare Centre Nearest facility Distance (in kms.)',
 'Maternity and Child Welfare Centre (Numbers)',
 'Maternity and Child Welfare Centre Beds (Numbers)',
 'Maternity and Child Welfare Centre Doctors-Total Strength (Numbers)',
 'Maternity and Child Welfare Centre Doctors-In Position (Numbers)',
 'Maternity and Child Welfare Centre Para Medical Staff-Total Strength (Numbers)',
 'Maternity and Child Welfare Centre Para Medical Staff-In Position (Numbers)',
 'Maternity and Child Welfare Centre Nearest facility Distance (in Kms.)\n',
 'Maternity Home (Numbers)',
 'Maternity Home Beds (Numbers)',
 'Maternity Home Doctors-Total Strength (Numbers)',
 'Maternity Home Doctors-In Position (Numbers)',
 'Maternity Home Para Medical Staff-Total Strength (Numbers)',
 'Maternity Home Para Medical Staff-In position (Numbers)',
 'Maternity Home Nearest facility Distance (in kms.)',
 'T.B. Hospital/ Clinic (Numbers)',
 'T.B. Hospital/ Clinic Beds (Numbers)',
 'T.B. Hospital/ Clinic Doctors-Total Strength (Numbers)',
 'T.B. Hospital/ Clinic Doctors-In Position (Numbers)',
 'T.B. Hospital/Clinic Para Medical Staff-Total Strength (Numbers)',
 'T.B. Hospital/Clinic Para Medical Staff-In position (Numbers)',
 'T.B. Hospital/ Clinic Nearest facility Distance (in kms.)',
 'Nursing Home (Numbers) ',
 'Nursing Home Beds (Numbers)',
 'Nursing Home Doctors-Total Strength (Numbers)',
 'Nursing Home Doctor-In Postion (Numbers)',
 'Nursing Home Para Medical Staff-Total Strength (Numbers)',
 'Nursing Home Para Medical Staff-In Position (Numbers)',
 'Nursing Home Nearest facility Distance (in kms.)',
 'Veterinary Hospital (Numbers)',
 'Veterinary Hospital Beds (Numbers)',
 'Veterinary Hospital Doctors-Total Strength (Numbers)',
 'Veterinary Hospital Doctors-In Position (Numbers)',
 'Veterinary Hospital Para Medical Staff-Total Strength (Numbers)',
 'Veterinary Hospital Para Medical Staff-In Position (Numbers)',
 'Veterinary Hospital Nearest facility Distance (in kms.)',
 'Mobile Health Clinic (Numbers)',
 'Mobile Health Clinic Beds (Numbers)',
 'Mobile Health Clinic Doctors-Total Strength (Numbers)',
 'Mobile Health Clinic Doctors-In Postion (Numbers)',
 'Mobile Health Clinic Para Medical Staff-Total Strength (Numbers)',
 'Mobile Health Clinic Para Medical Staff-In poistion (Numbers)',
 'Mobile Health Clinic Nearest facility Distance (in kms.)',
 'Others (Numbers)',
 'Others Beds (Numbes)',
 'Others Doctors-Total Strength (Numbers)',
 'Others Doctors-In Position (Numbers)',
 'Others Para Medical Staff-Total Strength (Numbers)',
 'Others Para Medical Staff-In Position (Numbers)',
 'Others Nearest facility Distance (in kms.)',
 'Non-Government Out-Patient (Numbers)',
 'Non-Government In and Out Patient (Numbers)',
 'Non-Government Charitable-Hospital/Nursing Home (Numbers)',
 'Non-Government Medicine Shop (Numbers)']]

# %%
df2.shape
# Out:
# (118, 98)

# %%
#interpolating cols with nans
for col in df2:
    if(df2[col].isnull().any() == True):
        df2[col].interpolate(limit=25, limit_direction='both', inplace=True)
#did not work on all cols dont know why yet
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:6035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
list1 = []
for col in df2:
    if(df2[col].isnull().any() == True):
        list1.append(col)
len(list1)
# Out:
# 3

# %%
list1
# Out:
# ['Hospital Allopathic Nearest facility Distance (in Kms.)',
#  'Maternity Home Beds (Numbers)',
#  'Others Nearest facility Distance (in kms.)']

# %%
df2['Hospital Allopathic Nearest facility Distance (in Kms.)'].fillna(0, inplace=True)
df2['Maternity Home Beds (Numbers)'].fillna(0, inplace=True)
df2['Others Nearest facility Distance (in kms.)'].fillna(0, inplace=True)
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df2[list1].isna().sum()
# Out:
# Hospital Allopathic Nearest facility Distance (in Kms.)    0
# Maternity Home Beds (Numbers)                              0
# Others Nearest facility Distance (in kms.)                 0
# dtype: int64

# %%
list2 = []
for col in df2:
    if(df2[col].isnull().any() == True):
        list2.append(col)
len(list2)
# Out:
# 0

# %%
index = df2.index

# %%
for i in index:
    if df2['Hospital Allopathic (Numbers)'][i] == 0:
        if df2['Hospital Allopathic Nearest facility Distance (in Kms.)'][i] <= 5:
            df2['Hospital Allopathic (Numbers)'][i] = 1
        if df2['Hospital Allopathic Nearest facility Distance (in Kms.)'][i] >5 and df2['Hospital Allopathic Nearest facility Distance (in Kms.)'][i] <= 10:
            df2['Hospital Allopathic (Numbers)'][i] = 0.5
        if df2['Hospital Allopathic Nearest facility Distance (in Kms.)'][i] > 10:
            df2['Hospital Allopathic (Numbers)'][i] = 0.1
    
    
    if df2['Hospital Alternative Medicine (Numbers)'][i] == 0:
        if df2['Hospital Alternative Medicine Nearest facility Distance(in kms.)'][i] <= 5:
            df2['Hospital Alternative Medicine (Numbers)'][i] = 1
        if df2['Hospital Alternative Medicine Nearest facility Distance(in kms.)'][i] >5 and df2['Hospital Alternative Medicine Nearest facility Distance(in kms.)'][i] <= 10:
            df2['Hospital Alternative Medicine (Numbers)'][i] = 0.5
        if df2['Hospital Alternative Medicine Nearest facility Distance(in kms.)'][i] > 10:
            df2['Hospital Alternative Medicine (Numbers)'][i] = 0.1
    
    
    if df2['Dispensary/Health Centre (Numbers)'][i] == 0:
        if df2['Dispensary/Health Centre Nearest facility Distance (in Kms.)'][i] <= 5:
            df2['Dispensary/Health Centre (Numbers)'][i] = 1
        if df2['Dispensary/Health Centre Nearest facility Distance (in Kms.)'][i] >5 and df2['Dispensary/Health Centre Nearest facility Distance (in Kms.)'][i] <= 10:
            df2['Dispensary/Health Centre (Numbers)'][i] = 0.5
        if df2['Dispensary/Health Centre Nearest facility Distance (in Kms.)'][i] > 10:
            df2['Dispensary/Health Centre (Numbers)'][i] = 0.1
            
            
    if df2['Family Welfare Centre (Numbers)'][i] == 0:
        if df2['Family Welfare Centre Nearest facility Distance (in kms.)'][i] <= 5:
            df2['Family Welfare Centre (Numbers)'][i] = 1
        if df2['Dispensary/Health Centre Nearest facility Distance (in Kms.)'][i] >5 and df2['Family Welfare Centre Nearest facility Distance (in kms.)'][i] <= 10:
            df2['Family Welfare Centre (Numbers)'][i] = 0.5
        if df2['Dispensary/Health Centre Nearest facility Distance (in Kms.)'][i] > 10:
            df2['Family Welfare Centre (Numbers)'][i] = 0.1
    
    
    if df2['Maternity and Child Welfare Centre (Numbers)'][i] == 0:
        if df2['Maternity and Child Welfare Centre Nearest facility Distance (in Kms.)\n'][i] <=5:
            df2['Maternity and Child Welfare Centre (Numbers)'][i] = 1
        if df2['Maternity and Child Welfare Centre Nearest facility Distance (in Kms.)\n'][i] >5 and df2['Maternity and Child Welfare Centre Nearest facility Distance (in Kms.)\n'][i] <=10:
            df2['Maternity and Child Welfare Centre (Numbers)'][i] = 0.5
        if df2['Maternity and Child Welfare Centre Nearest facility Distance (in Kms.)\n'][i] >10:
            df2['Maternity and Child Welfare Centre (Numbers)'][i] = 0.1
        
        
    if df2['Maternity Home (Numbers)'][i] == 0:
        if df2['Maternity Home Nearest facility Distance (in kms.)'][i] <= 5:
            df2['Maternity Home (Numbers)'][i] = 1
        if df2['Maternity Home Nearest facility Distance (in kms.)'][i] >5 and df2['Maternity Home Nearest facility Distance (in kms.)'][i] <=10:
            df2['Maternity Home (Numbers)'][i] = 0.5
        if df2['Maternity Home Nearest facility Distance (in kms.)'][i] >10:
            df2['Maternity Home (Numbers)'][i] = 0.1
        
        
            
    if df2['T.B. Hospital/ Clinic (Numbers)'][i] == 0:
        if df2['T.B. Hospital/ Clinic Nearest facility Distance (in kms.)'][i] <=5:
            df2['T.B. Hospital/ Clinic (Numbers)'][i] = 1
        if df2['T.B. Hospital/ Clinic Nearest facility Distance (in kms.)'][i] >5 and df2['T.B. Hospital/ Clinic Nearest facility Distance (in kms.)'][i] <= 10:
            df2['T.B. Hospital/ Clinic (Numbers)'][i] = 0.5
        if df2['T.B. Hospital/ Clinic Nearest facility Distance (in kms.)'][i] >10:
            df2['T.B. Hospital/ Clinic (Numbers)'][i] = 0.1
    if df2['Nursing Home (Numbers) '][i] == 0:
        if df2['Nursing Home Nearest facility Distance (in kms.)'][i] <= 5:
            df2['Nursing Home (Numbers) '][i] = 1
        if df2['Nursing Home Nearest facility Distance (in kms.)'][i] > 5 and df2['Nursing Home Nearest facility Distance (in kms.)'][i] <=10:
            df2['Nursing Home (Numbers) '][i] = 0.5
        if df2['Nursing Home Nearest facility Distance (in kms.)'][i] >10:
            df2['Nursing Home (Numbers) '][i] = 0.1
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/pratik/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
final1 = df2[["Town Name"]]

# %%
df2["Medical Facilities"] = df2['Hospital Allopathic (Numbers)'] + df2['Hospital Alternative Medicine (Numbers)'] + df2['Dispensary/Health Centre (Numbers)'] + df2['Family Welfare Centre (Numbers)'] + df2['Maternity and Child Welfare Centre (Numbers)'] + df2['Maternity Home (Numbers)'] + df2['T.B. Hospital/ Clinic (Numbers)'] + df2['Nursing Home (Numbers) '] + df2['Non-Government Out-Patient (Numbers)'] + df2['Non-Government In and Out Patient (Numbers)'] + df2['Non-Government Charitable-Hospital/Nursing Home (Numbers)'] + df2['Mobile Health Clinic (Numbers)'] + df2['Others (Numbers)']
df2["Tot doctors of town"] = df2['Hospital Allopathic Doctors-In Position (Numbers)'] + df2['Hospital Alternative Medicine Doctors-In Position (Numbers)'] + df2['Dispensary/Health Centre Doctors-In Position (Numbers)'] + df2['Family Welfare Centre Doctors-In Position (Numbers)'] + df2['Maternity and Child Welfare Centre Doctors-In Position (Numbers)'] + df2['Maternity Home Doctors-In Position (Numbers)'] + df2['T.B. Hospital/ Clinic Doctors-In Position (Numbers)'] + df2['Nursing Home Doctor-In Postion (Numbers)'] + df2['Mobile Health Clinic Doctors-In Postion (Numbers)'] + df2['Others Doctors-In Position (Numbers)']
df2["Maternity facilities"] = df2["Maternity and Child Welfare Centre (Numbers)"] + df2["Maternity Home (Numbers)"]
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
final1["Town-District Medical Centers Ratio"] = df2["Medical Facilities"] / df2["Medical Facilities"].sum()
final1["Town-District No of Doctors Ratio"] = df2["Tot doctors of town"] / df2["Tot doctors of town"].sum()
final1["Town-District maternity Facilities Ratio"] = df2["Maternity facilities"] / df2["Maternity facilities"].sum()
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
final1["Medical Facilities-Population Ratio"] = df2["Medical Facilities"] / df2['Total Population of Town']
final1["No of Doctors-Population Ratio"] = df2["Tot doctors of town"] / df2['Total Population of Town']
final1["Maternity Hospilats per Female Population"] = df2["Maternity facilities"] / df2['Total Female Population of Town']
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
final1["Medical Facilities per Area"] = df2["Medical Facilities"] / df2['Area (sq. km.)']
final1["No of Doctors per sq. km."] = df2["Tot doctors of town"] / df2['Area (sq. km.)']
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
final1["Medical Facilities per Town Density"] = df2["Medical Facilities"] / df2["Density (Census 2011)"]
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final1
# Out:
#                         Town Name  Town-District Medical Centers Ratio  \
# 751                Maheshtala (M)                             0.002036
# 752               Budge Budge (M)                             0.007197
# 753                    Pujali (M)                             0.018175
# 754           Rajpur Sonarpur (M)                             0.012505
# 755                  Baruipur (M)                             0.007052
# 756           Diamond Harbour (M)                             0.002617
# 757         Jaynagar Mazilpur (M)                             0.001890
# 758                     Joka (CT)                             0.000567
# 759          Chata Kalikapur (CT)                             0.000945
# 760       Ganye Gangadharpur (CT)                             0.000887
# 761              Rameswarpur (CT)                             0.001163
# 762                    Asuti (CT)                             0.001890
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(final1["Town-District Medical Centers Ratio"])
# Out:
# (array([117.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([1.16323029e-04, 8.01756478e-02, 1.60234973e-01, 2.40294297e-01,
#         3.20353622e-01, 4.00412947e-01, 4.80472271e-01, 5.60531596e-01,
#         6.40590921e-01, 7.20650246e-01, 8.00709570e-01]),
#  <a list of 10 Patch objects>)

# %%
'''for col in final1:
    if final1[col].dtype == "float64":
        final1[col] = (final1[col] - final1[col].min())/(final1[col].max() - final1[col].min())
'''
# Out:
# 'for col in final1:\n    if final1[col].dtype == "float64":\n        final1[col] = (final1[col] - final1[col].min())/(final1[col].max() - final1[col].min())\n'

# %%
index1 = final1.index
index1 = list(index1)

# %%
final1.describe()
# Out:
#        Town-District Medical Centers Ratio  Town-District No of Doctors Ratio  \
# count                           118.000000                         118.000000
# mean                              0.008475                           0.008475
# std                               0.073604                           0.027833
# min                               0.000116                           0.000000
# 25%                               0.000687                           0.000000
# 50%                               0.000894                           0.000000
# 75%                               0.001323                           0.004717
# max                               0.800710                           0.193396
#
#        Town-District maternity Facilities Ratio  \
# count                                118.000000
# mean                                   0.008475
# std                                    0.015393
# min                                    0.001062
# ...

# %%
final2 = pd.DataFrame(index = final1.index, columns=final1.columns)

# %%
for i in final1.index:
    for col in final1.columns:
        if final1[col].dtype == "float64":
            if final1[col][i] <= (final1[col].mean() + (3*final1[col].std())) and final1[col][i] >= (final1[col].mean() - (3*final1[col].std())):
                final2[col][i] = final1[col][i]

# %%
final2["Town Name"] = final1["Town Name"]
final2
# Out:
#                         Town Name Town-District Medical Centers Ratio  \
# 751                Maheshtala (M)                          0.00203565
# 752               Budge Budge (M)                          0.00719749
# 753                    Pujali (M)                           0.0181755
# 754           Rajpur Sonarpur (M)                           0.0125047
# 755                  Baruipur (M)                          0.00705208
# 756           Diamond Harbour (M)                          0.00261727
# 757         Jaynagar Mazilpur (M)                          0.00189025
# 758                     Joka (CT)                         0.000567075
# 759          Chata Kalikapur (CT)                         0.000945125
# 760       Ganye Gangadharpur (CT)                         0.000886963
# 761              Rameswarpur (CT)                          0.00116323
# 762                    Asuti (CT)                          0.00189025
# ...

# %%
for col in final2:
        if col != "Town Name":
            final2[col] = pd.to_numeric(final2[col])

# %%
final2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 751 to 868
# Data columns (total 10 columns):
# Town Name                                    118 non-null object
# Town-District Medical Centers Ratio          117 non-null float64
# Town-District No of Doctors Ratio            115 non-null float64
# Town-District maternity Facilities Ratio     117 non-null float64
# Medical Facilities-Population Ratio          117 non-null float64
# No of Doctors-Population Ratio               116 non-null float64
# Maternity Hospilats per Female Population    117 non-null float64
# Medical Facilities per Area                  117 non-null float64
# No of Doctors per sq. km.                    115 non-null float64
# Medical Facilities per Town Density          117 non-null float64
# dtypes: float64(9), object(1)
# memory usage: 15.1+ KB

# %%
for col in final2:
    final2[col].fillna(0, inplace=True)

# %%
final2.describe()
# Out:
#        Town-District Medical Centers Ratio  Town-District No of Doctors Ratio  \
# count                           118.000000                         118.000000
# mean                              0.001689                           0.004217
# std                               0.002706                           0.009935
# min                               0.000000                           0.000000
# 25%                               0.000629                           0.000000
# 50%                               0.000887                           0.000000
# 75%                               0.001236                           0.002162
# max                               0.018175                           0.056604
#
#        Town-District maternity Facilities Ratio  \
# count                                118.000000
# mean                                   0.007121
# std                                    0.006330
# min                                    0.000000
# ...

# %%
plt.hist(final2["Town-District Medical Centers Ratio"])
# Out:
# (array([97., 10.,  4.,  3.,  1.,  0.,  1.,  0.,  1.,  1.]),
#  array([0.        , 0.00181755, 0.00363509, 0.00545264, 0.00727019,
#         0.00908774, 0.01090528, 0.01272283, 0.01454038, 0.01635793,
#         0.01817547]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["Town-District No of Doctors Ratio"])
# Out:
# (array([95.,  8.,  4.,  3.,  1.,  3.,  2.,  1.,  0.,  1.]),
#  array([0.        , 0.00566038, 0.01132075, 0.01698113, 0.02264151,
#         0.02830189, 0.03396226, 0.03962264, 0.04528302, 0.0509434 ,
#         0.05660377]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["Town-District maternity Facilities Ratio"])
# Out:
# (array([51., 62.,  3.,  0.,  0.,  0.,  0.,  1.,  0.,  1.]),
#  array([0.        , 0.00536093, 0.01072187, 0.0160828 , 0.02144374,
#         0.02680467, 0.03216561, 0.03752654, 0.04288747, 0.04824841,
#         0.05360934]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["Medical Facilities-Population Ratio"])
# Out:
# (array([66., 34.,  7.,  3.,  2.,  1.,  1.,  2.,  1.,  1.]),
#  array([0.        , 0.00091941, 0.00183882, 0.00275823, 0.00367764,
#         0.00459705, 0.00551646, 0.00643587, 0.00735528, 0.00827469,
#         0.0091941 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["No of Doctors-Population Ratio"])
# Out:
# (array([94.,  4.,  8.,  1.,  3.,  0.,  2.,  4.,  1.,  1.]),
#  array([0.        , 0.00010484, 0.00020968, 0.00031452, 0.00041936,
#         0.0005242 , 0.00062904, 0.00073388, 0.00083872, 0.00094356,
#         0.0010484 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["Maternity Hospilats per Female Population"])
# Out:
# (array([50., 28., 20., 15.,  4.,  0.,  0.,  0.,  0.,  1.]),
#  array([0.        , 0.0002117 , 0.00042339, 0.00063509, 0.00084678,
#         0.00105848, 0.00127017, 0.00148187, 0.00169357, 0.00190526,
#         0.00211696]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["Medical Facilities per Area"])
# Out:
# (array([46., 39., 16.,  5.,  2.,  5.,  1.,  1.,  1.,  2.]),
#  array([ 0.        ,  2.47963413,  4.95926826,  7.43890239,  9.91853652,
#         12.39817064, 14.87780477, 17.3574389 , 19.83707303, 22.31670716,
#         24.79634129]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["No of Doctors per sq. km."])
# Out:
# (array([93., 11.,  4.,  2.,  3.,  1.,  0.,  2.,  1.,  1.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(final2["Medical Facilities per Town Density"])
# Out:
# (array([89., 17.,  4.,  2.,  1.,  0.,  1.,  1.,  1.,  2.]),
#  array([0.        , 0.0032156 , 0.0064312 , 0.00964679, 0.01286239,
#         0.01607799, 0.01929359, 0.02250919, 0.02572479, 0.02894038,
#         0.03215598]),
#  <a list of 10 Patch objects>)

# %%
final2["Total Score"] = 0.0

# %%
final2["Household-Area Ratio"] = df['Number of Households including Houseless Households (2011 Census)'] / df['Area (sq. km.)']

# %%
plt.hist(final2["Household-Area Ratio"])
# Out:
# (array([48., 42., 15.,  4.,  5.,  2.,  1.,  0.,  0.,  1.]),
#  array([ 292.28267856,  720.87730185, 1149.47192514, 1578.06654843,
#         2006.66117172, 2435.25579501, 2863.85041829, 3292.44504158,
#         3721.03966487, 4149.63428816, 4578.22891145]),
#  <a list of 10 Patch objects>)

# %%
final2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 751 to 868
# Data columns (total 12 columns):
# Town Name                                    118 non-null object
# Town-District Medical Centers Ratio          118 non-null float64
# Town-District No of Doctors Ratio            118 non-null float64
# Town-District maternity Facilities Ratio     118 non-null float64
# Medical Facilities-Population Ratio          118 non-null float64
# No of Doctors-Population Ratio               118 non-null float64
# Maternity Hospilats per Female Population    118 non-null float64
# Medical Facilities per Area                  118 non-null float64
# No of Doctors per sq. km.                    118 non-null float64
# Medical Facilities per Town Density          118 non-null float64
# Total Score                                  118 non-null float64
# Household-Area Ratio                         118 non-null float64
# dtypes: float64(11), object(1)
# memory usage: 17.0+ KB

# %%
final2["Total Score"] = (final2["Total Score"] - final2["Total Score"].min())/(final2["Total Score"].max() - final2["Total Score"].min())
final2["Household-Area Ratio"] = (final2["Household-Area Ratio"] - final2["Household-Area Ratio"].min()) / (final2["Household-Area Ratio"].max() - final2["Household-Area Ratio"].min())

# %%
final2.describe()
# Out:
#        Town-District Medical Centers Ratio  Town-District No of Doctors Ratio  \
# count                           118.000000                         118.000000
# mean                              0.001689                           0.004217
# std                               0.002706                           0.009935
# min                               0.000000                           0.000000
# 25%                               0.000629                           0.000000
# 50%                               0.000887                           0.000000
# 75%                               0.001236                           0.002162
# max                               0.018175                           0.056604
#
#        Town-District maternity Facilities Ratio  \
# count                                118.000000
# mean                                   0.007121
# std                                    0.006330
# min                                    0.000000
# ...

# %%
final2
# Out:
#                         Town Name  Town-District Medical Centers Ratio  \
# 751                Maheshtala (M)                             0.002036
# 752               Budge Budge (M)                             0.007197
# 753                    Pujali (M)                             0.018175
# 754           Rajpur Sonarpur (M)                             0.012505
# 755                  Baruipur (M)                             0.007052
# 756           Diamond Harbour (M)                             0.002617
# 757         Jaynagar Mazilpur (M)                             0.001890
# 758                     Joka (CT)                             0.000567
# 759          Chata Kalikapur (CT)                             0.000945
# 760       Ganye Gangadharpur (CT)                             0.000887
# 761              Rameswarpur (CT)                             0.001163
# 762                    Asuti (CT)                             0.001890
# ...

# %%
'''plt.scatter(x=final2["Total Score"], y=final2["Household-Area Ratio"])
plt.xlabel("Total Medical Index Score")
plt.ylabel("Household-Area Ratio")'''
# Out:
# 'plt.scatter(x=final2["Total Score"], y=final2["Household-Area Ratio"])\nplt.xlabel("Total Medical Index Score")\nplt.ylabel("Household-Area Ratio")'

# %%
for col in final2:
    if final2[col].dtype != "object":
        final2[col] = (final2[col] - final2[col].min()) / (final2[col].max() - final2[col].min())

# %%
final2.describe()
# Out:
#        Town-District Medical Centers Ratio  Town-District No of Doctors Ratio  \
# count                           118.000000                         118.000000
# mean                              0.092922                           0.074506
# std                               0.148885                           0.175512
# min                               0.000000                           0.000000
# 25%                               0.034600                           0.000000
# 50%                               0.048800                           0.000000
# 75%                               0.068000                           0.038194
# max                               1.000000                           1.000000
#
#        Town-District maternity Facilities Ratio  \
# count                                118.000000
# mean                                   0.132824
# std                                    0.118079
# min                                    0.000000
# ...

# %%
final2.corr()
# Out:
#                                            Town-District Medical Centers Ratio  \
# Town-District Medical Centers Ratio                                   1.000000
# Town-District No of Doctors Ratio                                     0.001906
# Town-District maternity Facilities Ratio                              0.129539
# Medical Facilities-Population Ratio                                   0.587703
# No of Doctors-Population Ratio                                        0.231431
# Maternity Hospilats per Female Population                            -0.096849
# Medical Facilities per Area                                           0.589942
# No of Doctors per sq. km.                                             0.293984
# Medical Facilities per Town Density                                   0.854150
# Total Score                                                                NaN
# Household-Area Ratio                                                  0.037374
#
# ...

# %%
for col in final2:
    if final2[col].dtype == "float64":
        plt.scatter(final2[col], final2["Household-Area Ratio"])
        plt.xlabel(col)
        plt.ylabel("Household/area")
        plt.show()

# %%
final2.columns
# Out:
# Index(['Town Name', 'Town-District Medical Centers Ratio',
#        'Town-District No of Doctors Ratio',
#        'Town-District maternity Facilities Ratio',
#        'Medical Facilities-Population Ratio', 'No of Doctors-Population Ratio',
#        'Maternity Hospilats per Female Population',
#        'Medical Facilities per Area', 'No of Doctors per sq. km.',
#        'Medical Facilities per Town Density', 'Total Score',
#        'Household-Area Ratio'],
#       dtype='object')

# %%
final3 = final2[['Town-District Medical Centers Ratio',
       'Town-District No of Doctors Ratio',
       'Medical Facilities-Population Ratio', 'No of Doctors-Population Ratio',
       'Medical Facilities per Area', 'No of Doctors per sq. km.',
       'Medical Facilities per Town Density',
       'Household-Area Ratio']]

# %%
x = final3[['Town-District Medical Centers Ratio',
       'Town-District No of Doctors Ratio',
       'Medical Facilities-Population Ratio', 'No of Doctors-Population Ratio',
       'Medical Facilities per Area', 'No of Doctors per sq. km.',
       'Medical Facilities per Town Density']]

# %%
y = final2[["Household-Area Ratio"]]

# %%
# Import
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# Out:
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# PolynomialFeatures (prepreprocessing)
poly = PolynomialFeatures(degree=3)
X_ = poly.fit_transform(x)
X_test_ = poly.fit_transform(x_test)

# %%
lr1 = LinearRegression()

# %%
lr1.fit(X_,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
accuracy = lr1.score(X_test_, y_test)

# %%
accuracy
# Out:
# 0.9949914278464906

# %%
X_.shape
# Out:
# (118, 120)

# %%
lr1.coef_.shape
# Out:
# (1, 120)

# %%
weights = np.transpose(lr1.coef_)
weights.shape
# Out:
# (120, 1)

# %%
scores = np.matmul(X_, weights)

# %%
final2["Total Score"] = scores

# %%
final2
# Out:
#                         Town Name  Town-District Medical Centers Ratio  \
# 751                Maheshtala (M)                               0.1120
# 752               Budge Budge (M)                               0.3960
# 753                    Pujali (M)                               1.0000
# 754           Rajpur Sonarpur (M)                               0.6880
# 755                  Baruipur (M)                               0.3880
# 756           Diamond Harbour (M)                               0.1440
# 757         Jaynagar Mazilpur (M)                               0.1040
# 758                     Joka (CT)                               0.0312
# 759          Chata Kalikapur (CT)                               0.0520
# 760       Ganye Gangadharpur (CT)                               0.0488
# 761              Rameswarpur (CT)                               0.0640
# 762                    Asuti (CT)                               0.1040
# ...

# %%
final2.corr()
# Out:
#                                            Town-District Medical Centers Ratio  \
# Town-District Medical Centers Ratio                                   1.000000
# Town-District No of Doctors Ratio                                     0.001906
# Town-District maternity Facilities Ratio                              0.129539
# Medical Facilities-Population Ratio                                   0.587703
# No of Doctors-Population Ratio                                        0.231431
# Maternity Hospilats per Female Population                            -0.096849
# Medical Facilities per Area                                           0.589942
# No of Doctors per sq. km.                                             0.293984
# Medical Facilities per Town Density                                   0.854150
# Total Score                                                           0.037857
# Household-Area Ratio                                                  0.037374
#
# ...

# %%
#checking 
final2["Population-Area Ratio"]  = df['Town Population (Census 2011)'] / df['Area (sq. km.)']
final2["Electricity-Area Ratio"] = df['Electricity-Domestic Connection (Numbers)'] / df['Area (sq. km.)']

# %%
final2.corr()
# Out:
#                                            Town-District Medical Centers Ratio  \
# Town-District Medical Centers Ratio                                   1.000000
# Town-District No of Doctors Ratio                                     0.001906
# Town-District maternity Facilities Ratio                              0.129539
# Medical Facilities-Population Ratio                                   0.587703
# No of Doctors-Population Ratio                                        0.231431
# Maternity Hospilats per Female Population                            -0.096849
# Medical Facilities per Area                                           0.589942
# No of Doctors per sq. km.                                             0.293984
# Medical Facilities per Town Density                                   0.854150
# Total Score                                                           0.037857
# Household-Area Ratio                                                  0.037374
# ...
