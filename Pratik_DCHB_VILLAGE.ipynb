# %%
import pandas as pd 
import numpy as np
df = pd.read_excel('/home/pratik/Downloads/DCHB_Village_Release_1900.xlsx')
pd.options.display.max_seq_items = 2000
# Out:
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pratik/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df1 = df[df['District Name'] == 'South Twenty Four Parganas']
df1.shape
# Out:
# (2044, 396)

# %%
df1.columns
# Out:
# Index(['State Code', 'State Name', 'District Code', 'District Name',
#        'Sub District Code', 'Sub District Name', 'Village Code',
#        'Village Name', 'CD Block Code', 'CD Block Name', 'Gram Panchayat Code',
#        'Gram Panchayat Name', 'Reference Year',
#        'Sub District Head Quarter (Name)',
#        'Sub District Head Quarter (Distance in km)',
#        'District Head Quarter  (Name)',
#        'District Head Quarter  (Distance in km)',
#        'Nearest Statutory Town  (Name)',
#        'Nearest Statutory Town (Distance in km)', 'Within the State/UT (Name)',
#        'Within the State/UT (Distance in km)',
#        'Outside the State/UT, if nearest one is not within the State/UT (Name)',
#        'Outside the State/UT distance, if nearest one is not within the State/UT (Distance in km)',
#        'Total Geographical Area (in Hectares)', 'Total   Households ',
#        'Total Population of Village', 'Total Male Population of Village',
# ...

# %%
df2 = df1[[ 'Village Name','Total Geographical Area (in Hectares)', 'Total   Households ',
       'Total Population of Village', 'Total Male Population of Village',
       'Total Female Population of Village','Community Health Centre (Numbers)',
       'Community Health Centre Doctors Total Strength (Numbers)',
       'Community Health Centre Doctors In Position (Numbers)',
       'Community Health Centre Para Medical  Staff Total Strength (Numbers)',
       'Community Health Centre Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .14',
       'Primary Health Centre (Numbers)',
       'Primary Health Centre  Doctors Total Strength (Numbers)',
       'Primary Health  Centre Doctors In Position (Numbers)',
       'Primary  Health Centre Para Medical  Staff Total Strength (Numbers)',
       'Primary  Health Centre Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .15',
       'Primary Heallth Sub Centre (Numbers)',
       'Primary Heallth Sub Centre Doctors Total Strength (Numbers)',
       'Primary Heallth Sub Centre Doctors In Position (Numbers)',
       'Primary Heallth Sub Centre Para Medical  Staff Total Strength (Numbers)',
       'Primary Heallth Sub Centre Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .16',
       'Maternity And Child Welfare Centre (Numbers)',
       'Maternity And Child Welfare Centre Doctors Total Strength (Numbers)',
       'Maternity And Child Welfare Centre Doctors In Position (Numbers)',
       'Maternity And Child Welfare Centre Para Medical  Staff Total Strength (Numbers)',
       'Maternity And Child Welfare Centre Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .17',
       'TB Clinic (Numbers)', 'TB Clinic Doctors Total Strength (Numbers)',
       'TB Clinic Doctors In Position (Numbers)',
       'TB Clinic Para Medical Para Medical  Staff Total Strength (Numbers)',
       'TB Clinic Para Medical Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .18',
       'Hospital Allopathic (Numbers)',
       'Hospital Allopathic Doctors Total Strength (Numbers)',
       'Hospital Allopathic Doctors In Position (Numbers)',
       'Hospital Allopathic Para Medical  Staff Total Strength (Numbers)',
       'Hospital Allopathic Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .19',
       'Hospiltal Alternative Medicine (Numbers)',
       'Hospiltal Alternative Medicine Doctors Total Strength (Numbers)',
       'Hospiltal Alternative Medicine Doctors In Position (Numbers)',
       'Hospiltal Alternative Medicine Para Medical  Staff Total Strength (Numbers)',
       'Hospiltal Alternative Medicine Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .20',
       'Dispensary (Numbers)', 'Dispensary Doctors Total Strength (Numbers)',
       'Dispensary Doctors In Position (Numbers)',
       'Dispensary Para Medical  Staff Total Strength (Numbers)',
       'Dispensary Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .21',
       'Veterinary Hospital (Numbers)',
       'Veterinary Hospital Doctors Total Strength (Numbers)',
       'Veterinary Hospital Doctors In Position (Numbers)',
       'Veterinary Hospital Para Medical  Staff Total Strength (Numbers)',
       'Veterinary Hospital Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .22',
       'Mobile Health Clinic (Numbers)',
       'Mobile Health Clinic Doctors Total Strength (Numbers)',
       'Mobile Health Clinic Doctors In Position (Numbers)',
       'Mobile Health Clinic Para Medical  Staff Total Strength (Numbers)',
       'Mobile Health Clinic Para Medical Staff In Position(Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .23',
       'Family Welfare Centre (Numbers)',
       'Family Welfare Centre Doctors Total Strength (Numbers)',
       'Family Welfare Centre Doctors In Position (Numbers)',
       'Family Welfare Centre Para Medical  Staff Total Strength (Numbers)',
       'Family Welfare Centre Para Medical Staff In Position (Numbers)',
       '(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .24',
       'Non Government Medical facilities Out Patient (Numbers)',
       'Non Government Medical facilities In And Out Patient (Numbers)',
       'Non Government Medical facilities Charitable (Numbers)',
       'Non Government Medical facilities Medical Prctitioner with MBBS Degree (Numbers) ',
       'Non Government Medical facilities Medical Prctitioner with other Degree (Numbers)  ',
       'Non Government Medical facilities Medical Practitioner with no  Degree (Numbers) ',
       'Non Government Medical facilities Traditional Practitioner and Faith  Healer (Numbers) ',
       'Non Government Medical facilities Medicine Shop (Numbers) ',
       'Non Government Medical facilities Others (Numbers)',
 ]]
df2.shape
# Out:
# (2044, 81)

# %%
for col in df2:
    if(df2[col].isnull().any() == True):
        df2[col].interpolate(limit=25, limit_direction='both', inplace=True)
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:6035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
list1 = []
for col in df2:
    if(df2[col].isnull().any() == True):
        list1.append(col)
len(list1)
# Out:
# 16

# %%
for col in list1:
    df2[col].fillna(0, inplace=True)
#MISSING VALUES REPLACED
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
index = df2.index

# %%
for i in index:
    if df2['Community Health Centre (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .14'] [i] == 'a':
            df2['Community Health Centre (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .14'] [i] == 'b':
            df2['Community Health Centre (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .14'] [i] == 'c':
            df2['Community Health Centre (Numbers)'][i] = 0.1
            
    if df2['Primary Health Centre (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .15'][i] == 'a':
            df2['Primary Health Centre (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .15'][i] == 'b':
            df2['Primary Health Centre (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .15'][i] == 'c':
            df2['Primary Health Centre (Numbers)'][i] = 0.1
    if df2['Primary Heallth Sub Centre (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .16'][i] == 'a':
            df2['Primary Heallth Sub Centre (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .16'][i] == 'b':
            df2['Primary Heallth Sub Centre (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .16'][i] == 'c':   
            df2['Primary Heallth Sub Centre (Numbers)'][i] = 0.1
            
    if df2['Maternity And Child Welfare Centre (Numbers)'][i]  == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .17'][i] == 'a':
            df2['Maternity And Child Welfare Centre (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .17'][i] == 'b':
            df2['Maternity And Child Welfare Centre (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .17'][i] == 'c':
            df2['Maternity And Child Welfare Centre (Numbers)'][i] = 0.1
    if df2['TB Clinic (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .18'][i] == 'a':
            df2['TB Clinic (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .18'][i] == 'b':
            df2['TB Clinic (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .18'][i] == 'c':
            df2['TB Clinic (Numbers)'][i] = 0.1
    
    
    if df2['Hospital Allopathic (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .19'][i] == 'a':
            df2['Hospital Allopathic (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .19'][i] == 'b':
            df2['Hospital Allopathic (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .19'][i] == 'c':    
            df2['Hospital Allopathic (Numbers)'][i] = 0.1
    
    
    if df2['Hospiltal Alternative Medicine (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .20'][i] == 'a':
            df2['Hospiltal Alternative Medicine (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .20'][i] == 'b':
            df2['Hospiltal Alternative Medicine (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .20'][i] == 'c':
            df2['Hospiltal Alternative Medicine (Numbers)'][i] = 0.1
    
    if df2['Dispensary (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .21'][i] == 'a':
            df2['Dispensary (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .21'][i] == 'b':
            df2['Dispensary (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .21'][i] == 'c':
            df2['Dispensary (Numbers)'][i] = 0.1
    
    
    if df2['Mobile Health Clinic (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .23'][i] == 'a':
            df2['Mobile Health Clinic (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .23'][i] == 'a':    
            df2['Mobile Health Clinic (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .23'][i] == 'a':    
            df2['Mobile Health Clinic (Numbers)'][i] = 0.1
    
    if df2['Family Welfare Centre (Numbers)'][i] == 0:
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .24'][i] == 'a':
            df2['Family Welfare Centre (Numbers)'][i] = 1
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .24'][i] == 'b':
            df2['Family Welfare Centre (Numbers)'][i] = 0.5
        if df2['(If not available within the village, the distance range  code  of nearest place where  facility is available is given viz;  a for < 5 Kms, b for 5-10 Kms and c  for 10+ kms ).  .24'][i] == 'c':  
            df2['Family Welfare Centre (Numbers)'][i] = 0.1
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/pratik/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# ...

# %%
df2.head()
# Out:
#                 Village Name  Total Geographical Area (in Hectares)  \
# 26481               Sibhugli                                  91.30
# 26482            Chak Chhata                                  47.41
# 26483           Jagannathpur                                  54.23
# 26484  Saupukuria-Sanpukuria                                 122.75
# 26485             Chandigarh                                  89.40
#
#        Total   Households   Total Population of Village  \
# 26481                447.0                         2180
# 26482                643.0                         2779
# 26483                551.0                         2250
# 26484                496.0                         2297
# 26485                505.0                         2335
#
#        Total Male Population of Village  Total Female Population of Village  \
# 26481                            1134.0                              1046.0
# ...

# %%
df2["Total Medical Facilities"] = df2['Community Health Centre (Numbers)'] + df2['Primary Health Centre (Numbers)'] + df2['Primary Heallth Sub Centre (Numbers)'] + df2 ['Maternity And Child Welfare Centre (Numbers)'] + df2 ['TB Clinic (Numbers)'] + df2 ['Hospital Allopathic (Numbers)'] + df2 ['Hospiltal Alternative Medicine (Numbers)'] + df2 ['Dispensary (Numbers)'] + df2 ['Mobile Health Clinic (Numbers)'] + df2 ['Family Welfare Centre (Numbers)'] + df2 ['Non Government Medical facilities Out Patient (Numbers)'] + df2 ['Non Government Medical facilities In And Out Patient (Numbers)'] + df2 ['Non Government Medical facilities Charitable (Numbers)'] + df2 ['Non Government Medical facilities Medical Prctitioner with MBBS Degree (Numbers) '] + df2 ['Non Government Medical facilities Medicine Shop (Numbers) '] + df2 ['Non Government Medical facilities Others (Numbers)']
